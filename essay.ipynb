# %%
from langchain.document_loaders import TextLoader

# %%
loader = TextLoader("./ttt.txt")
data = loader.load()

# %%
data
# Out:
# [Document(page_content="Hello, sir. I hope you're doing well. My name is Hamza Jakouk. I'm 22 years old and a student at the National School of Applied Science. My academic journey began in 2019 when I started my two-year preparatory cycle. After that, I had the chance to start my engineering path in the field of information systems and big data. Right now, I'm in my graduation year. I noticed your post on LinkedIn, and I was thrilled by the opportunity. In fact, Artefact is a highly renowned company in the field, a dream for many. I've had the opportunity to work on many projects and gain experience with various technologies. In terms of my professional experience, I've completed three internships.\nDuring the most recent one  at Marsa Maroc, I develop a chatbot designed to assist the worker in efficiently addressing and resolving boat issues, thereby enhancing their repair processes.To accomplish this, I began by visiting boat workplaces to study how the engines work and identify t
# ...

# %%
data[0].page_content
# Out:
# "Hello, sir. I hope you're doing well. My name is Hamza Jakouk. I'm 22 years old and a student at the National School of Applied Science. My academic journey began in 2019 when I started my two-year preparatory cycle. After that, I had the chance to start my engineering path in the field of information systems and big data. Right now, I'm in my graduation year. I noticed your post on LinkedIn, and I was thrilled by the opportunity. In fact, Artefact is a highly renowned company in the field, a dream for many. I've had the opportunity to work on many projects and gain experience with various technologies. In terms of my professional experience, I've completed three internships.\nDuring the most recent one  at Marsa Maroc, I develop a chatbot designed to assist the worker in efficiently addressing and resolving boat issues, thereby enhancing their repair processes.To accomplish this, I began by visiting boat workplaces to study how the engines work and identify the most common problems
# ...

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(urls=["https://cultea.fr/one-piece-guide-complet-des-episodes-liste-fillers-arcs.html","https://python.langchain.com/docs/integrations/providers/wikipedia"])
data = loader.load()
data[0]
# Out:
# Document(page_content='animes Asie\n\n«\xa0One Piece\xa0» : liste complète des épisodes (guide fillers & arcs)\n\nBy Robin Uzan\n\nPosted on2023-08-102023-08-15\n\nTime to Read:\n\nwords\n\nOne Piece est sans conteste l’un des animes les plus cultes de tous les temps. Mais avec plus de 1000 épisodes et une diffusion qui continue, il est parfois difficile de savoir où donner de la tête… Dans cette liste dédiée à\xa0One Piece, vous trouverez la liste des épisodes, des arcs et des fillers, afin de mieux vous y retrouver.\n\nNota Bene : cette liste comporte plus de 1000 épisodes et s’inspire de plusieurs sources, parfois contradictoires. En cas d’erreur ou d’imprécision, merci de nous le signaler (dans la joie et la bonne humeur). Bonne lecture !\n\nNota Bene 2 : voici le code couleur pour les semi-fillers et fillers\n\nOne Piece saison 1 : liste des épisodes (01-61)\n\nArc du Colonel Morgan\n\nÉpisode 01 : Je suis Luffy ! Celui qui deviendra le Seigneur des Pirates !\n\nÉpisode 02 : L’a
# ...

# %%
# !apt-get install -y libmagic-dev
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !apt-get install -y libmagic-dev
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os 
import streamlit as st
import pickle
import time
import langchain
from langchain import OpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.qa_with_sources.loading import load_qa_with_sources_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

# %%
os.environ.get("OPENAI_API_KEY")
# Out:
# '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'

# %%
llm = OpenAI(temperature=0.7, max_token = 500)

loaders = UnstructuredURLLoader(urls=["https://www.usatoday.com/money/blueprint/investing/stock-forecast-tesla/","https://python.langchain.com/docs/integrations/providers/wikipedia" , "https://www.forbes.com/advisor/investing/tesla-stock-forecast/"])
data = loaders.load()
len(data)
# Out:
# c:\Users\Hinnovis\anaconda3\envs\mlops\lib\site-packages\langchain\utils\utils.py:159: UserWarning: WARNING! max_token is not default parameter.
#                 max_token was transferred to model_kwargs.
#                 Please confirm that max_token is what you intended.
#   warnings.warn(
# 3

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size =1000,
    chunk_overlap =200 , 
)

docs = text_splitter.split_documents(data)
len(docs)
# Out:
# 128

# %%
docs[5]
# Out:
# Document(page_content='Tesla reported its first profitable year in 2020 and became the largest company ever added to the S&P 500 in December 2020.\n\nTesla stock price\n\nTesla went public at an initial public offering price of $17 in 2010, but it has since split its stock twice. Tesla completed a five-for-one split in 2020 and a three-for-one split in 2022. Therefore, a single share of Tesla’s IPO stock would represent 15 shares of today’s TSLA stock.\n\nTesla gained 743% in 2020 after the company finally met the profitability requirement for inclusion in the S&P 500. Tesla was by far the best-performing stock in the S&P 500 in 2020, more than doubling the return of any other stock in the index. An EV-buying frenzy on Wall Street sent Tesla’s market capitalization soaring from less than $90 billion at the beginning of 2020 to more than $650 billion by year’s end, despite Tesla reporting just 28.3% revenue growth that year.', metadata={'source': 'https://www.usatoday.com/money/bluepr
# ...

# %%
embeddings = OpenAIEmbeddings()

vectorindex_openai = FAISS.from_documents(docs, embeddings)

# %%
file_path = "./vectorindex"

# %%
with open("vectorindex", 'wb') as f:
    pickle.dump(vectorindex_openai, f)
